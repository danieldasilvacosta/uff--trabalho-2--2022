# %%
import pandas as pd

# %%
df = pd.read_csv( 
    './datasets/pt_bosque-ud-train--pos.conllu',
    sep = '\t' )
df
# Out:
#           _          _.1          _.2    _.3 _.4  \
# 0         1           PT           PT  PROPN   _
# 1       2-3           no            _      _   _
# 2         2           em           em    ADP   _
# 3         3            o            o    DET   _
# 4         4      governo      governo   NOUN   _
# ...     ...          ...          ...    ...  ..
# 184561   29           os            o    DET   _
# 184562   30     invictos      invicto    ADJ   _
# 184563   31      Seattle      Seattle  PROPN   _
# 184564   32  Supersonics  Supersonics  PROPN   _
# 184565   33            .            .  PUNCT   _
#
#                                                       _.5 _.6        _.7 _.8  \
# 0                                 Gender=Masc|Number=Sing   0       root   _
# 1                                                       _   _          _   _
# 2                                                       _   4       case   _
# 3       Definite=Def|Gender=Masc|Number=Sing|PronType=Art   4        det   _
# 4                                 Gender=Masc|Number=Sing   1       nmod   _
# ...                                                   ...  ..        ...  ..
# 184561  Definite=Def|Gender=Masc|Number=Plur|PronType=Art  31        det   _
# 184562                            Gender=Masc|Number=Plur  31       amod   _
# 184563               ExtPos=PROPN|Gender=Masc|Number=Plur  27  obl:agent   _
# 184564                                        Number=Sing  31  flat:name   _
# 184565                                                  _  12      punct   _
#
#                   _.9
# 0                   _
# 1                   _
# 2                   _
# 3                   _
# 4                   _
# ...               ...
# 184561              _
# 184562              _
# 184563              _
# 184564  SpaceAfter=No
# 184565              _
#
# [184566 rows x 10 columns]

# %%
df = pd.read_csv( 
    './datasets/pt_bosque-ud-test--pos.conllu',
    sep = '\t' )
df
# Out:
#            _        _.1        _.2    _.3 _.4  \
# 0          1      Folha      Folha  PROPN   _
# 1          2         --         --  PUNCT   _
# 2          3       Como       como    ADV   _
# 3          4       você       você   PRON   _
# 4          5    recebeu    receber   VERB   _
# ...      ...        ...        ...    ...  ..
# 29615  36-37         da          _      _   _
# 29616     36         de         de    ADP   _
# 29617     37          a          o    DET   _
# 29618     38  avaliação  avaliação   NOUN   _
# 29619     39          .          .  PUNCT   _
#
#                                                      _.5 _.6        _.7 _.8  \
# 0                                 Gender=Fem|Number=Sing   0       root   _
# 1                                                      _   1      punct   _
# 2                                                      _   5     advmod   _
# 3             Case=Nom|Number=Sing|Person=3|PronType=Prs   5      nsubj   _
# 4      Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...   1  parataxis   _
# ...                                                  ...  ..        ...  ..
# 29615                                                  _   _          _   _
# 29616                                                  _  38       case   _
# 29617   Definite=Def|Gender=Fem|Number=Sing|PronType=Art  38        det   _
# 29618                             Gender=Fem|Number=Sing  35        obl   _
# 29619                                                  _   3      punct   _
#
#                  _.9
# 0                  _
# 1                  _
# 2                  _
# 3                  _
# 4                  _
# ...              ...
# 29615              _
# 29616              _
# 29617              _
# 29618  SpaceAfter=No
# 29619              _
#
# [29620 rows x 10 columns]

# %%
df = pd.read_csv( 
    './datasets/pt_bosque-ud-dev--pos.conllu',
    sep = '\t' )
df
# Out:
#          _        _.1        _.2    _.3 _.4  \
# 0        1   Pequenos    pequeno   NOUN   _
# 1        2        são        ser    AUX   _
# 2        3    agentes     agente   NOUN   _
# 3      4-5        das          _      _   _
# 4        4         de         de    ADP   _
# ...    ...        ...        ...    ...  ..
# 30505    9  acontecer  acontecer   VERB   _
# 30506   10          a          a    ADP   _
# 30507   11       este       este    DET   _
# 30508   12      corpo      corpo   NOUN   _
# 30509   13          .          .  PUNCT   _
#
#                                                      _.5 _.6    _.7 _.8  \
# 0                                Gender=Masc|Number=Plur   3  nsubj   _
# 1      Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...   3    cop   _
# 2                                Gender=Masc|Number=Plur   0   root   _
# 3                                                      _   _      _   _
# 4                                                      _   6   case   _
# ...                                                  ...  ..    ...  ..
# 30505                                       VerbForm=Inf   8  xcomp   _
# 30506                                                  _  12   case   _
# 30507               Gender=Masc|Number=Sing|PronType=Dem  12    det   _
# 30508                            Gender=Masc|Number=Sing   9    obj   _
# 30509                                                  _   5  punct   _
#
#                  _.9
# 0                  _
# 1                  _
# 2                  _
# 3                  _
# 4                  _
# ...              ...
# 30505              _
# 30506              _
# 30507              _
# 30508  SpaceAfter=No
# 30509              _
#
# [30510 rows x 10 columns]
